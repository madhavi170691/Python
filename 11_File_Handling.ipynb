# %% [markdown]
# # Mount files on drive!!!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #File Handling :

# %%
# The open function takes two parameter - filename and mode
# There are four different methods to open a file

#'r' - reads a default value
#'a' - opens the file for append and creates a file if it does not exist
#'w' - opens a file for writing
#'x' - creates a file

# Syntax :
# to open a file or read a file
f = open ("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt")
f
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt' mode='r' encoding='utf-8'>

# %%
# another way to open a file
with open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt", encoding='latin-1') as file:
  xy = file.read()

# %%
xy
# Out:
# 'Hi!!!!!!\nHow are you????\nThis is python session\x85.\n'

# %%
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt", encoding='latin-1')
f.readline() # one line at a time --> first line
# Out:
# 'Hi!!!!!!\n'

# %%
print(f.readline()) # second line
print(f.readline()) # third line
print(f.readline())
print(f.readline())
# Out:
# How are you????
#
# This is python session.

# %%
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt", encoding='latin-1')
f.readlines() # each line separated with comma (type list) and all the lines at once
# Out:
# ['Hi!!!!!!\n', 'How are you????\n', 'This is python session\x85.\n']

# %%
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt","r", encoding='latin-1') #read
print(f.read()) # reads content in the file
# Out:
# Hi!!!!!!
# How are you????
# This is python session.

# %%
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt","r", encoding='latin-1') #read
f.read(10) # read first 10 characters
# Out:
# 'Hi!!!!!!\nH'

# %%
# Write to an existing file
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt","a", encoding='latin-1')  # create or append
f.write("Now the file executed successfully")
f.close()

# %%
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture.txt","r", encoding='latin-1')
f.read() # observe one extra line is added
# Out:
# 'Hi!!!!!!\nHow are you????\nThis is python session\x85.\nNow the file executed successfully'

# %%
# Creating a new file
f = open("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture_python.txt","x", encoding='latin-1')  # create
f.write('New file')
f.close()

# %%
# Delete a file
# To delete a file, you must import the OS module, and run its os.remove() function:
import os
os.remove("/content/drive/MyDrive/VAC (Sadiya)/1. Batch_16th_March(VAC)/Python/Data/Lecture_python.txt")
